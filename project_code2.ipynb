# %%
#Dependencies
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

all_data = "datascientist/alldata.csv"

all_data_read = pd.read_csv(all_data)

all_data_read.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
#Got rid of all NA values in the dataset
all_data_read = all_data_read.dropna()
all_data_read.head()
# Out:
#                                             position             company  \
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
# 5                        Manager of Data Engineering  McKinsey & Company
# 6       Product Specialist - Periscope, New Ventures  McKinsey & Company
# 7  Junior to Mid-level Engineer, Geologist or Env...                Wood
#
#                                          description  reviews  \
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
# 5  Qualifications\nBachelor’s degree in Computer ...    385.0
# 6  Qualifications\nBachelor’s degree\n5-7 years o...    385.0
# 7  Overview / Responsibilities\nWood Environment ...    899.0
#
#              location
# 3  Atlanta, GA 30303
# 4         Atlanta, GA
# 5  Atlanta, GA 30318
# 6  Atlanta, GA 30318
# 7         Atlanta, GA

# %%
#Created dataframe for top five locations
locations = all_data_read["location"]

data_locations = pd.DataFrame(locations.value_counts())

data_locations.head(5)

five_locations = data_locations.head(5)
five_locations
# Out:
#                    location
# Seattle, WA             474
# Cambridge, MA           368
# New York, NY            338
# Boston, MA              305
# San Francisco, CA       287

# %%
# Making a bar graph based on the top five locations where most jobs are posted
total_jobs = [474, 368, 338, 305, 287]
x_axis = np.arange(len(five_locations))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Seattle", "Cambridge", "New York", "Boston", "San Francisco"])
plt.bar(x_axis, total_jobs, color='r', alpha=0.5, align="center")
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(250, max(total_jobs)+50)
plt.title("Top Five Cities for Data Scientist Jobs in the United States")
plt.xlabel("Top Five Cities")
plt.ylabel("Total Number of Jobs Posted")
# Save an image of the chart and print it to the screen
plt.savefig("Images/Top_five_cities.png")
plt.show()

# %%
#Which five companies have the most Data Science jobs in US
companies = all_data_read["company"]

data_company = pd.DataFrame(companies.value_counts())

data_company.head(5)

five_company = data_company.head(5)
five_company
# Out:
#                     company
# Amazon.com              357
# Ball Aerospace          187
# Microsoft               137
# Google                  134
# NYU Langone Health       76

# %%
#Created pie chart to display top five companies in US
total_companies = [357, 187, 137, 134, 76]
labels = ["Amazon", "Ball Aerospace", "Microsoft", "Google", "NYU Langone Health"]
colors = ["red", "orange", "lightcoral", "lightskyblue", "green"]

explode = [0.1, 0, 0, 0, 0]

plt.pie(total_companies, labels=labels, explode=explode, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")

plt.title("Top Five Companies for Data Scientist Jobs in the United States")

# Save an image of the chart and print it to the screen
plt.savefig("Images/Top_five_companies.png")
plt.show()

# %%
#What positions/jobs are available in this field
position = all_data_read["position"]

data_position = pd.DataFrame(position.value_counts())

data_position.head(5)

five_position = data_position.head(5)
five_position
# Out:
#                            position
# Data Scientist                  204
# Senior Data Scientist            53
# Research Analyst                 44
# Data Engineer                    39
# Machine Learning Engineer        26

# %%
#Created dataframe to display which positions are available in this field
df = pd.DataFrame({'Total Jobs Available': [204, 53, 44, 39, 26], 'position': ["Data Scientist", "Senior Data Scientist", "Research Analyst", "Data Engineer", "Machine \nLearning Engineer"]})
df.plot.barh(x='position', y='Total Jobs Available', figsize=(15,5))
plt.xlim([20,210])



# Save an image of the chart and print it to the screen
plt.savefig("Images/Top_five_jobs.png")
plt.show()

# %%
#Pull in data/jobs specfic to Austin
atx_data = "datascientist/fulltimeAT.csv"

atx_data_read = pd.read_csv(atx_data)

atx_data_read = atx_data_read.dropna()
#atx_description = atx_data_read["description"]
#atx_description_fixed = pd.DataFrame(atx_description)
#atx_description_fixed
atx_data_read.head()
# Out:
#                                             position  \
# 0                      Senior Scientist, Development
# 1                             Data Software Engineer
# 2                           Bioinformatics Scientist
# 3  Research Engineering/ Scientist Associate II -...
# 4                                Lead Data Scientist
#
#                          company  \
# 0                       Asuragen
# 1                         Kelvin
# 2                   Premierehire
# 3  University of Texas at Austin
# 4            Clockwork Solutions
#
#                                          description    numreview  \
# 0  <span id="job_summary" class="summary"><div><d...    8 reviews
# 1  <span id="job_summary" class="summary"><div><b...    5 reviews
# 2  <span id="job_summary" class="summary"><p>CONT...    5 reviews
# 3  <span id="job_summary" class="summary"><div><d...  772 reviews
# 4  <span id="job_summary" class="summary"><div><p...    5 reviews
#
#            location
# 0        Austin, TX
# 1        Austin, TX
# 2        Austin, TX
# 3        Austin, TX
# 4  Austin, TX 78746

# %%
#Which companies in Austin have the most data science jobs
atx_companies = atx_data_read["company"]

atx_data_company = pd.DataFrame(atx_companies.value_counts())

atx_data_company.head(5)

atx_five_company = atx_data_company.head(5)
atx_five_company
# Out:
#                                company
# University of Texas at Austin       23
# Advanced Micro Devices, Inc.         8
# Natera                               8
# DELL                                 7
# ICF                                  6

# %%
#text = atx_description.iloc[0]
#import re
#atx_description_fixed['text'] = pd.apply(lambda x: re.sub(r'\<+[^\>]+\>', '', x))

# %%
#Which languages/skills are these companies looking for
skills = ["Python", "R", "SQL", "Java", "C++"]
def skills_count(text):
    skills = ["Python", "R", "SQL", "Java", "C++"]
    skilsdict = {"Python": 0, "R": 0, "SQL": 0, "Java": 0, "C++": 0}
    for x in skills:
        for t in text.split(' '):
            if x.lower() == t.lower():
                skilsdict[x]+= 1
    return skilsdict.values()
all_data_read['description'].apply(skills_count)
all_data_read['Python'], all_data_read['R'], all_data_read["SQL"], all_data_read["Java"], all_data_read["C++"] = zip(*all_data_read['description'].apply(skills_count))

# %%
#Total languages added together to get most popular languages
all_data_read
python = all_data_read['Python'].sum()
r = all_data_read['R'].sum()
java = all_data_read['Java'].sum()
c = all_data_read['C++'].sum()

# %%
#Dataframe to display these languages
skills_df = [python, r, java, c]
skills_df = pd.DataFrame((skills_df), columns=['Most Desired Skills'], index=["Python", "R", "Java", "C++"])
skills_df
# Out:
#         Most Desired Skills
# Python                  728
# R                       438
# Java                    236
# C++                     123

# %%
# Making a bar graph based on the top five locations where most jobs are posted
atx_total_jobs = [23, 8, 8, 7, 6]
x_axis = np.arange(len(atx_five_company))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["UT", "AMD", "Natera", "DELL", "ICF"])
plt.bar(x_axis, atx_total_jobs, color='g', alpha=0.5, align="center")
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(2, max(atx_total_jobs)+1)
plt.title("Top Five Companies for Data Scientist Jobs in Austin")
plt.xlabel("Top Five Companies")
plt.ylabel("Total Number of Jobs Posted")
# Save an image of the chart and print it to the screen
plt.savefig("Images/Top_five_companies_atx.png")
plt.show()

# %%
#five_locations.iloc[0]
#title = 'Seattle Vs Austin Job Market for Data Scientist'
#Pie_plot_agg(filter_column= five_locations.iloc[0],
 #           column = data_location.iloc[12],
  #          title = title,
   #         name = ['United States of America','India', 'China', 'Russia'],
    #        width = 1000, height =800)

# %%
#Donut chart to display the most popular languages
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

skill = ["728 Python",
          "438 R",
          "236 Java",
          "123 C++",
          ]

data = [728, 438, 236, 123]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(skill[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Most Desired Languages in the United States")

# Save an image of the chart and print it to the screen
plt.savefig("Images/most_desired_skills.png")
plt.show()

# %%
#API for Heat Map of Jobs across US
import gmaps

# Google developer API key
#from config import gkey

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
# Create a list containing coordinates
coordinates = [
    (33.74, -84.38),
    (30.26, -97.74),
    (40.01, -105.27),
    (42.36, -71.05),
    (41.87, -87.62),
    (38.90, -77.03),
    (34.05, -118.24),
    (42.37, -71.10),
    (37.38, -122.08),
    (40.71, -74.00),
    (47.60, -120.12),
    (32.71, -117.61),
    (47.60, -122.33),
    (37.77, -122.41),
    (37.36, -122.03)
]

new_locations = ["Atlanta", "Austin", "Boulder", "Boston", "Chicago", "Washington DC", "Los Angeles", "Cambridge, MA", "Mountain View, CA", "New York", "Redmond, WA", "San Diego", "Seattle", "San Francisco", "Sunnyvale, CA"]

jobs_for_locations = [114, 127, 219, 305, 224, 159, 126, 368, 138, 338, 112, 238, 474, 287, 185]

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=jobs_for_locations, 
                                 dissipating=False, max_intensity=300,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Add Austin row to compare to top five cities

data_for_compare = data_locations.head(12)

data_for_compare
# Out:
#                    location
# Seattle, WA             474
# Cambridge, MA           368
# New York, NY            338
# Boston, MA              305
# San Francisco, CA       287
# San Diego, CA           238
# Chicago, IL             224
# Boulder, CO             219
# Sunnyvale, CA           185
# Washington, DC          159
# Mountain View, CA       138
# Austin, TX              127

# %%
#Only jobs posted for Amazon.com
amazon_df = all_data_read[all_data_read['company'].str.contains("Amazon.com")]
amazon_df.head()
# Out:
#                                               position     company  \
# 79   Technical Evangelist – Database, Analytics, an...  Amazon.com
# 105                     Business Intelligence Engineer  Amazon.com
# 284                         Machine Learning Scientist  Amazon.com
# 401  Software Development Engineer, Homepage Person...  Amazon.com
# 802   Research Scientist - Natural Language Processing  Amazon.com
#
#                                            description  reviews     location  \
# 79   Job Description\nDo you love data? Do you like...  25907.0  Atlanta, GA
# 105  Job Description\nAmazon Transportation Service...  25907.0  Atlanta, GA
# 284  Job Description\nDo you want to help build a h...  25902.0   Austin, TX
# 401  Job Description\nAmazon’s mission is to be the...  25902.0   Austin, TX
# 802  Job Description\nInterested in Amazon Echo? We...  25902.0   Boston, MA
#
#      Python  R  SQL  Java  C++
# 79        0  0    0     0    0
# 105       0  0    0     0    0
# 284       0  0    0     0    0
# 401       0  0    0     1    0
# 802       0  0    0     0    0

# %%
#Skills that Amazon is looking for
python_a = amazon_df['Python'].sum()
r_a = amazon_df['R'].sum()
java_a = amazon_df['Java'].sum()
c_a = amazon_df['C++'].sum()

# %%
#Dataframe for Amazon Skills
amazon_skills = [python_a, r_a, java_a, c_a]
amazon_skills_df = pd.DataFrame((amazon_skills), columns=['Most Desired Skills For Amazon'], index=["Python", "R", "Java", "C++"])
amazon_skills_df
# Out:
#         Most Desired Skills For Amazon
# Python                              60
# R                                   25
# Java                                23
# C++                                  6

# %%
#Donut chart to display most popular languages for Amazon
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

skill_amazon = ["60 Python",
          "25 R",
          "23 Java",
          "6 C++",
          ]

data_amazon = [60, 25, 23, 6]

wedges, texts = ax.pie(data_amazon, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(skill_amazon[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Most Desired Languages at Amazon")

# Save an image of the chart and print it to the screen
plt.savefig("Images/most_skills_Amazon.png")
plt.show()

# %%
#Only jobs posted for Austin
atx_data_read['description'].apply(skills_count)
atx_data_read['Python'], atx_data_read['R'], atx_data_read["SQL"], atx_data_read["Java"], atx_data_read["C++"] = zip(*atx_data_read['description'].apply(skills_count))

# %%
#Find the total skills for Austin
python_atx = atx_data_read['Python'].sum()
r_atx = atx_data_read['R'].sum()
java_atx = atx_data_read['Java'].sum()
c_atx = atx_data_read['C++'].sum()

# %%
#Dataframe for Austin Skills
austin_skills = [python_atx, r_atx, java_atx, c_atx]
austin_skills_df = pd.DataFrame((austin_skills), columns=['Most Desired Languages For Austin Jobs'], index=["Python", "R", "Java", "C++"])
austin_skills_df
# Out:
#         Most Desired Languages For Austin Jobs
# Python                                      30
# R                                            8
# Java                                        20
# C++                                         11

# %%
#Donut chart to display most popular languages for Austin
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

skill_atx = ["30 Python",
          "8 R",
          "20 Java",
          "11 C++",
          ]

data_atx = [30, 8, 20, 11]

wedges, texts = ax.pie(data_atx, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(skill_atx[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Most Desired Languages in Austin")

# Save an image of the chart and print it to the screen
plt.savefig("Images/most_skills_ATX.png")
plt.show()
